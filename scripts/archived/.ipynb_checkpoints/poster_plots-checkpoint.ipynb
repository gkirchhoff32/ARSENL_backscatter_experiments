# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import os, sys

cwd = os.getcwd()
dirLib = cwd + r'/../library'
if dirLib not in sys.path:
    sys.path.append(dirLib)
    
from load_ARSENL_data import set_binwidth

# %%
load_loc = r'C:\Users\Grant\OneDrive - UCB-O365\ARSENL\Experiments\Deadtime_Experiments\Figures\evaluation_loss\compare_deadtime_poisson'
fname_dead = r'\deadtimeTrueOD2.5_use_sim_False.pkl'
fname_pois = r'\deadtimeFalseOD2.5_use_sim_False.pkl'

use_sim_data = False

infile_dead = open(load_loc+fname_dead, 'rb')
infile_pois = open(load_loc+fname_pois, 'rb')
load_dead = pickle.load(infile_dead)
load_pois = pickle.load(infile_pois)

# %%
load_dead
# Out:
# [[<xarray.DataArray 'time_tag' (time_tag_index: 101109)>
#   array([2.9325e-08, 2.8500e-08, 2.8300e-08, ..., 2.8400e-08, 2.8475e-08,
#          2.8150e-08])
#   Dimensions without coordinates: time_tag_index,
#   <xarray.DataArray 'time_tag' (time_tag_index: 100903)>
#   array([2.9100e-08, 2.8850e-08, 2.9150e-08, ..., 2.9850e-08, 2.8725e-08,
#          2.8325e-08])
#   Dimensions without coordinates: time_tag_index,
#   <xarray.DataArray 'time_tag' (time_tag_index: 100980)>
#   array([2.8450e-08, 2.8500e-08, 2.8650e-08, ..., 2.8650e-08, 2.9025e-08,
#          2.8325e-08])
#   Dimensions without coordinates: time_tag_index,
#   <xarray.DataArray 'time_tag' (time_tag_index: 100880)>
#   array([2.835e-08, 2.815e-08, 2.855e-08, ..., 2.880e-08, 2.855e-08,
#          2.850e-08])
#   Dimensions without coordinates: time_tag_index,
#   <xarray.DataArray 'time_tag' (time_tag_index: 99992)>
#   array([2.8375e-08, 2.8400e-08, 2.8775e-08, ..., 2.9050e-08, 2.8750e-08,
#          2.8625e-08])
#   Dimensions without coordinates: time_tag_index,
#   <xarray.DataArray 'time_tag' (time_tag_index: 96327)>
#   array([2.8800e-08, 2.8525e-08, 3.0450e-08, ..., 3.0150e-08, 2.8875e-08,
#          2.9050e-08])
#   Dimensions without coordinates: time_tag_index,
#   <xarray.DataArray 'time_tag' (time_tag_index: 91376)>
#   array([2.9725e-08, 2.9875e-08, 2.9125e-08, ..., 2.9300e-08, 2.8725e-08,
#          2.9700e-08])
#   Dimensions without coordinates: time_tag_index,
#   <xarray.DataArray 'time_tag' (time_tag_index: 80922)>
#   array([3.0000e-08, 2.9875e-08, 3.0300e-08, ..., 2.9050e-08, 2.9525e-08,
#          2.9575e-08])
#   Dimensions without coordinates: time_tag_index,
#   <xarray.DataArray 'time_tag' (time_tag_index: 73381)>
#   array([3.1825e-08, 3.0425e-08, 3.0375e-08, ..., 2.9175e-08, 2.8875e-08,
#          2.9225e-08])
#   Dimensions without coordinates: time_tag_index,
#   <xarray.DataArray 'time_tag' (time_tag_index: 63899)>
#   array([2.9475e-08, 2.9200e-08, 2.9025e-08, ..., 2.8950e-08, 2.9100e-08,
#          2.9425e-08])
#   Dimensions without coordinates: time_tag_index,
#   <xarray.DataArray 'time_tag' (time_tag_index: 38770)>
#   array([2.9450e-08, 2.9625e-08, 2.9750e-08, ..., 2.9250e-08, 2.8950e-08,
#          2.9650e-08])
#   Dimensions without coordinates: time_tag_index,
#   <xarray.DataArray 'time_tag' (time_tag_index: 29010)>
#   array([2.955e-08, 3.100e-08, 2.910e-08, ..., 3.020e-08, 3.000e-08,
#          2.900e-08])
#   Dimensions without coordinates: time_tag_index,
#   <xarray.DataArray 'time_tag' (time_tag_index: 24631)>
#   array([2.9725e-08, 3.0800e-08, 3.1600e-08, ..., 2.9250e-08, 2.9175e-08,
#          2.9150e-08])
#   Dimensions without coordinates: time_tag_index,
#   <xarray.DataArray 'time_tag' (time_tag_index: 20349)>
#   array([2.9200e-08, 3.0000e-08, 3.0700e-08, ..., 2.9900e-08, 3.0200e-08,
#          2.9825e-08])
#   Dimensions without coordinates: time_tag_index,
#   <xarray.DataArray 'time_tag' (time_tag_index: 14508)>
#   array([2.9625e-08, 2.9650e-08, 2.9750e-08, ..., 3.0525e-08, 2.9475e-08,
#          3.0350e-08])
#   Dimensions without coordinates: time_tag_index,
#   <xarray.DataArray 'time_tag' (time_tag_index: 8484)>
#   array([3.0050e-08, 2.9675e-08, 2.9425e-08, ..., 3.1025e-08, 2.9525e-08,
#          2.9925e-08])
#   Dimensions without coordinates: time_tag_index,
#   <xarray.DataArray 'time_tag' (time_tag_index: 6917)>
#   array([2.9825e-08, 2.9450e-08, 2.9050e-08, ..., 3.0200e-08, 2.8975e-08,
#          3.0000e-08])
#   Dimensions without coordinates: time_tag_index,
#   <xarray.DataArray 'time_tag' (time_tag_index: 6157)>
#   array([2.9675e-08, 3.0625e-08, 3.0250e-08, ..., 3.0100e-08, 2.9450e-08,
#          2.9500e-08])
#   Dimensions without coordinates: time_tag_index,
#   <xarray.DataArray 'time_tag' (time_tag_index: 5671)>
#   array([2.8925e-08, 3.0875e-08, 3.0800e-08, ..., 3.0250e-08, 2.9675e-08,
#          2.9600e-08])
#   Dimensions without coordinates: time_tag_index],
#  2.75e-08,
#  3.35e-08,
#  2.5e-11,
#  100007]

# %%
if use_sim_data:
    t_fine = load_dead[0]
    fit_rate_seg_dead = load_dead[1]
    true_flight_time = load_dead[2]
    true_rho = load_dead[3]
    flight_time = load_dead[4]
    n_shots = load_dead[5]
    t_min = load_dead[6]
    t_max = load_dead[7]
    dt = load_dead[8]

    fit_rate_seg_pois = load_pois[1]
else:
    t_fine = load_dead[0]
    fit_rate_seg_dead = load_dead[1]
    flight_time = load_dead[2]
    n_shots = load_dead[3]
    t_min = load_dead[4]
    t_max = load_dead[5]
    dt = load_dead[6]

    fit_rate_seg_pois = load_pois[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
#      17 n_shots = load_dead[3]
#      18 t_min = load_dead[4]
# ---> 19 t_max = load_dead[5]
#      20 dt = load_dead[6]
#      22 fit_rate_seg_pois = load_pois[1]
#
# IndexError: list index out of range

# %%
fig = plt.figure(figsize=(6,4), dpi=400)
ax = fig.add_subplot(111)
bin_array = set_binwidth(t_min, t_max, dt)
if use_sim_data:
    n, bins = np.histogram(true_flight_time, bins=bin_array)
    binwidth = np.diff(bins)[0]
    N = n / binwidth / n_shots  # [Hz] Scaling counts to arrival rate
    center = 0.5 * (bins[:-1] + bins[1:])
    ax.bar(center, N, align='center', width=binwidth, color='orange', alpha=0.5, label='Incident Photons')

    ax.plot(t_fine, true_rho, '--', color='orange', label='True Arrival Rate')
    n, bins = np.histogram(flight_time, bins=bin_array)
    binwidth = np.diff(bins)[0]
    N = n / binwidth / n_shots  # [Hz] Scaling counts to arrival rate
    center = 0.5 * (bins[:-1] + bins[1:])
    ax.bar(center, N, align='center', width=binwidth, color='blue', alpha=0.5, label='Detected Photons')
else:
    n, bins = np.histogram(flight_time, bins=bin_array)
    binwidth = np.diff(bins)[0]
    N = n / binwidth / n_shots  # [Hz] Scaling counts to arrival rate
    center = 0.5 * (bins[:-1] + bins[1:])
    ax.bar(center, N, align='center', width=binwidth, color='blue', alpha=0.5, label='Detected Photons')

# Arrival rate fit
ax.plot(t_fine, fit_rate_seg_dead, '-.', markersize=5, color='blue', label='Fit: Deadtime Model')
ax.plot(t_fine, fit_rate_seg_pois, '-.', markersize=5, color='black', label='Fit: Poisson Model')
ax.set_title('Arrival Rate Fit')
ax.set_xlabel('time [s]')
ax.set_ylabel('Photon Arrival Rate [Hz]')
# props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
# ax.text(0.1, 0.3, 'Polynomial order: {}'.format(order), transform=ax.transAxes, fontsize=14,
#         verticalalignment='top', bbox=props)
plt.tight_layout()
plt.legend()

save_dir = r'C:\Users\Grant\Downloads'
save_plt_file = r'\{}.png'.format(fname_dead)
fig.savefig(save_dir + save_plt_file)
plt.show()
