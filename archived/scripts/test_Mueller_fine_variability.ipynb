# %%
import os, sys
import numpy as np
import time
import matplotlib.pyplot as plt
import xarray as xr
import scipy
from pathlib import Path

# from generate_sim_data import gen_rho, gen_sim_data
from load_ARSENL_data import load_INPHAMIS_data, set_binwidth, data_dir, fname, picklename

import matplotlib as mpl
mpl.rcParams.update({"figure.facecolor": "white"})

# %% [markdown]
# # Mueller Correction on Fine Targets Using Coarse Resolution
#
# This test is to confirm that the Mueller correction can only be applied to uniform scenes. This is to clarify that this is a scene-defined issue, not a user-defined one. Simply smoothing over high-variability targets (i.e., targets that vary on the order of the deadtime interval) results in inaccurate estimates when using the Mueller correction. To test this, I simulate a scene with a singular, narrow Gaussian pulse accumulated at high resolution (i.e., sub-pulse-width resolution). Then I bin to a single large bin that satisfies the Mueller requirement ($\Delta t\gg\tau$).
#
# If $\rho(t)$ is gaussian, then the true average value over a single bin (of width $T$) is
# $$\bar{\rho}(t)=\frac{1}{T}\int_{0}^{T}\rho(t')dt'=\frac{1}{T}\int_{0}^{T}\left(A\exp(-\frac{(t'-\mu)^2}{2\sigma^2})+b\right)dt'$$
# $$\bar{\rho}(t)=\frac{1}{T}\sqrt{\frac{\pi}{2}}A\sigma\left(erf\left(\frac{T-\mu}{\sqrt{2}\sigma}\right)-erf\left(-\frac{\mu}{\sqrt{2}\sigma}\right)\right)+b$$
#
# This value is compared to the Mueller corrected estimate:
# $$\hat{\rho}=\frac{\rho_m}{1-\rho_m\tau}$$
# where $\rho_m=\frac{N}{TN_{shots}}$. $N$ is the total accumulated counts in the single bin.

# %% [markdown]
# # Generate Simulated Data

# %%
home = str(Path.home())
save_dir = home + r'\OneDrive - UCB-O365\ARSENL\Experiments\SPCM\Data\Simulated\Muller_Test_Simulated'

# %%
# amplitude = np.array([2.5e5, 5e5, 1e6, 2.5e6, 5e6, 1e7, 2.5e7, 5e7, 1e8])  # [Hz]
# amplitude = np.array([5e7, 1e8, 2.5e8, 5e8])  # [Hz]
# amplitude = np.array([6.25e6, 7.5e6, 8.75e6])
amplitude = np.logspace(7,8,15)

# simulation resolution settings
t_sim_min = 0  # [s]
t_sim_max = 2000e-9  # [s]
dt_sim = 25e-9  # [s]

tD = 25e-9  # [s] deadtime
Nshot = int(1e5)  # number of laser shots
wrap_deadtime = False  # wrap deadtime between shots
window_bnd = [t_sim_min, t_sim_max]  # [s] time-of-flight bounds
laser_pulse_width = 250e-9  # [s] laser pulse width (sigma)
target_time = 1000e-9  # [s] target location in time
background = 1e1  # [Hz] background count rate (dark count)

# %%
for i in range(len(amplitude)):
    
    target_amplitude = amplitude[i]
    
    ### GENERATE SIMULATED DATA ###
    det_idx, phot_idx, sync_idx, det_sync_idx, phot_sync_idx, det_events, phot_events = gen_sim_data(t_sim_max, dt_sim,
                                                                                                     tD, Nshot,
                                                                                                     wrap_deadtime,
                                                                                                     window_bnd,
                                                                                                     laser_pulse_width,
                                                                                                     target_time,
                                                                                                     target_amplitude,
                                                                                                     background)

    time_tag_index = det_idx
    true_time_tag_index = phot_idx
    sync_index = sync_idx
    time_tag = det_events
    true_time_tag = phot_events
    time_tag_sync_index = det_sync_idx
    true_time_tag_sync_index = phot_sync_idx

    # Save simulated data to netCDF
    sim_data = xr.Dataset(
        data_vars=dict(
            time_tag=(['time_tag_index'], time_tag),
            time_tag_sync_index=(['time_tag_index'], time_tag_sync_index),
            true_time_tag=(['true_time_tag_index'], true_time_tag),
            true_time_tag_sync_index=(['true_time_tag_index'], true_time_tag_sync_index),
            laser_pulse_width=laser_pulse_width,
            target_time=target_time,
            target_amplitude=target_amplitude,
            background=background,
            t_sim_min=t_sim_min,
            t_sim_max=t_sim_max,
            dt_sim=dt_sim,
            tD=tD,
            window_bnd=window_bnd,
            wrap_deadtime=wrap_deadtime
        ),
        coords=dict(
            sync_index=(['sync_index'], sync_index)
        )
    )

    fname = r'\sim_amp{:.1E}_nshot{:.1E}_pwidth_{:.1E}.nc'.format(target_amplitude, Nshot, laser_pulse_width*1e9)
    sim_data.to_netcdf(save_dir+fname)
# Out:
# time elapsed: 111.21214985847473
# time elapsed: 129.10380816459656
# time elapsed: 144.38225436210632
# time elapsed: 173.27765560150146
# time elapsed: 202.71756601333618
# time elapsed: 232.44907999038696
# time elapsed: 275.0434582233429
# time elapsed: 321.3969748020172
# time elapsed: 377.9271025657654
# time elapsed: 441.2933361530304
# time elapsed: 516.4296538829803
# time elapsed: 611.4900557994843
# time elapsed: 739.1606469154358
# time elapsed: 873.1700813770294
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~\Anaconda\envs\arsenl-conda\lib\site-packages\xarray\backends\api.py:1072, in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf)
#    1069 try:
#    1070     # TODO: allow this work (setting up the file for writing array data)
#    1071     # to be parallelized with dask
# -> 1072     dump_to_store(
#    1073         dataset, store, writer, encoding=encoding, unlimited_dims=unlimited_dims
#    1074     )
#    1075     if autoclose:
#
# File ~\Anaconda\envs\arsenl-conda\lib\site-packages\xarray\backends\api.py:1119, in dump_to_store(dataset, store, writer, encoder, encoding, unlimited_dims)
#    1117     variables, attrs = encoder(variables, attrs)
# -> 1119 store.store(variables, attrs, check_encoding, writer, unlimited_dims=unlimited_dims)
#
# File ~\Anaconda\envs\arsenl-conda\lib\site-packages\xarray\backends\common.py:265, in AbstractWritableDataStore.store(self, variables, attributes, check_encoding_set, writer, unlimited_dims)
#     264 self.set_dimensions(variables, unlimited_dims=unlimited_dims)
# --> 265 self.set_variables(
#     266     variables, check_encoding_set, writer, unlimited_dims=unlimited_dims
#     267 )
#
# File ~\Anaconda\envs\arsenl-conda\lib\site-packages\xarray\backends\common.py:307, in AbstractWritableDataStore.set_variables(self, variables, check_encoding_set, writer, unlimited_dims)
#     303 target, source = self.prepare_variable(
#     304     name, v, check, unlimited_dims=unlimited_dims
#     305 )
# --> 307 writer.add(source, target)
#
# File ~\Anaconda\envs\arsenl-conda\lib\site-packages\xarray\backends\common.py:156, in ArrayWriter.add(self, source, target, region)
#     155 else:
# --> 156     target[...] = source
#
# File ~\Anaconda\envs\arsenl-conda\lib\site-packages\xarray\backends\netCDF4_.py:72, in BaseNetCDF4Array.__setitem__(self, key, value)
#      71 data = self.get_array(needs_lock=False)
# ---> 72 data[key] = value
#      73 if self.datastore.autoclose:
#
# File src\netCDF4\_netCDF4.pyx:5283, in netCDF4._netCDF4.Variable.__setitem__()
#
# File src\netCDF4\_netCDF4.pyx:5564, in netCDF4._netCDF4.Variable._put()
#
# File src\netCDF4\_netCDF4.pyx:1965, in netCDF4._netCDF4._ensure_nc_success()
#
# RuntimeError: NetCDF: HDF error
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
#      24 sim_data = xr.Dataset(
#      25     data_vars=dict(
#      26         time_tag=(['time_tag_index'], time_tag),
#    (...)
#      43     )
#      44 )
#      46 fname = r'\sim_amp{:.1E}_nshot{:.1E}_pwidth_{:.1E}.nc'.format(target_amplitude, Nshot, laser_pulse_width*1e9)
# ---> 47 sim_data.to_netcdf(save_dir+fname)
#
# File ~\Anaconda\envs\arsenl-conda\lib\site-packages\xarray\core\dataset.py:1901, in Dataset.to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf)
#    1898     encoding = {}
#    1899 from ..backends.api import to_netcdf
# -> 1901 return to_netcdf(
#    1902     self,
#    1903     path,
#    1904     mode,
#    1905     format=format,
#    1906     group=group,
#    1907     engine=engine,
#    1908     encoding=encoding,
#    1909     unlimited_dims=unlimited_dims,
#    1910     compute=compute,
#    1911     invalid_netcdf=invalid_netcdf,
#    1912 )
#
# File ~\Anaconda\envs\arsenl-conda\lib\site-packages\xarray\backends\api.py:1088, in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf)
#    1086 finally:
#    1087     if not multifile and compute:
# -> 1088         store.close()
#    1090 if not compute:
#    1091     import dask
#
# File ~\Anaconda\envs\arsenl-conda\lib\site-packages\xarray\backends\netCDF4_.py:513, in NetCDF4DataStore.close(self, **kwargs)
#     512 def close(self, **kwargs):
# --> 513     self._manager.close(**kwargs)
#
# File ~\Anaconda\envs\arsenl-conda\lib\site-packages\xarray\backends\file_manager.py:222, in CachingFileManager.close(self, needs_lock)
#     220 file = self._cache.pop(self._key, default)
#     221 if file is not None:
# --> 222     file.close()
#
# File src\netCDF4\_netCDF4.pyx:2511, in netCDF4._netCDF4.Dataset.close()
#
# File src\netCDF4\_netCDF4.pyx:2475, in netCDF4._netCDF4.Dataset._close()
#
# File src\netCDF4\_netCDF4.pyx:1965, in netCDF4._netCDF4._ensure_nc_success()
#
# RuntimeError: NetCDF: HDF error

# %%
# Analytic average of true function
subdir = r'\subset_pwidth_2.5E+02\\'

erf = scipy.special.erf
files = os.listdir(save_dir + subdir)

t_sim_min = 0  # [s]

true_flux = np.zeros(len(files))
det_flux = np.zeros(len(files))
muller_flux = np.zeros(len(files))
for i in range(len(files)):
    fname = files[i]
    ds = xr.open_dataset(save_dir + subdir + fname)

    start = time.time()

    cnts = ds.time_tag
#     dt = ds.dt_sim
    dt = 25e-12  # [s]
    flight_time = cnts * dt  # [s]
    # Exclude specified t.o.f. bins
    flight_time = flight_time[np.where((flight_time >= window_bnd[0]) & (flight_time < window_bnd[1]))]
    n_shots = len(ds.sync_index)
    
    A = ds.target_amplitude.to_numpy()  # [Hz]
    sigma = ds.laser_pulse_width  # [s]
    mu = ds.target_time  # [s]
    b = ds.background  # [Hz]
#     t_sim_max = ds.t_sim_max
    t_sim_max = 2e-6  # [s]
#     tD = ds.tD
    tD = 25e-9  # [s]
    
    T = t_sim_max - t_sim_min

    ds.close()
    
    bin_array = set_binwidth(t_sim_min, t_sim_max, dt)
    n, bins = np.histogram(flight_time, bins=bin_array)

    # Detected flux over single bin
    n_tot = np.sum(n)
    binwidth_tot = T  # [s]
    rho_avg_det = n_tot / binwidth_tot / n_shots  # [Hz]

    # True flux over single bin
    rho_avg_true = 1/T*(np.sqrt(np.pi/2)*A*sigma*erf((T-mu)/np.sqrt(2)/sigma)+b*T-np.sqrt(np.pi/2)*A*sigma*erf(-mu/np.sqrt(2)/sigma))  # [Hz]

    # Apply Muller correction
    rho_avg_Muller = rho_avg_det / (1 - tD*rho_avg_det)
    
    true_flux[i] = rho_avg_true
    det_flux[i] = rho_avg_det
    muller_flux[i] = rho_avg_Muller
    
sort_idx = np.argsort(true_flux)
true_flux = true_flux[sort_idx]
det_flux = det_flux[sort_idx]
muller_flux = muller_flux[sort_idx]

# %%
fig = plt.figure(figsize=(6,4), dpi=400)
plt.rcParams.update({'font.size': 15})
ax = fig.add_subplot(111)
# ax.plot(true_flux[2:-2], true_flux[2:-2], linestyle='--', color='k', label='True Flux')
# ax.plot(true_flux[2:-2], det_flux[2:-2], marker='.', color='b', label='Observed Flux')
# ax.plot(true_flux[2:-2], muller_flux[2:-2], marker='.', color='m', label='Müller Corrected Flux')
ax.plot(true_flux/1e6, true_flux/1e6, linestyle='--', color='k', label='True Flux')
ax.plot(true_flux/1e6, muller_flux/1e6, color='magenta', label='Standard Correction')
ax.plot(true_flux/1e6, det_flux/1e6, color='#800020', linestyle='-.', label='Detected Flux')
ax.set_xlabel('True Flux (Coarse) [MHz]')
ax.set_ylabel('Detected Flux (Coarse) [MHz]')
# ax.set_yscale('log')
# ax.set_xscale('log')
plt.legend()
plt.legend(loc='upper left', prop={'size': 12})
plt.tight_layout()
plt.show()

# %% [markdown]
# # View Simulated Data

# %%
fname = r'\sim_amp2.5E+07_nshot1.0E+06_pwidth_1.2E+02.nc'
subdir = r'\subset_pwidth_1.2E+02\\'
ds = xr.open_dataset(save_dir + subdir + fname)

start = time.time()

cnts = ds.time_tag
cnts_true = ds.true_time_tag
tau = ds.tD
dt = dt_sim
flight_time = cnts * dt  # [s]
true_flight_time = cnts_true * dt  # [s]
# Exclude specified t.o.f. bins
flight_time = flight_time[np.where((flight_time >= window_bnd[0]) & (flight_time < window_bnd[1]))]
true_flight_time = true_flight_time[np.where((true_flight_time >= window_bnd[0]) & (true_flight_time < window_bnd[1]))]
n_shots = len(ds.sync_index)

ds.close()

bin_array = set_binwidth(t_sim_min, t_sim_max, dt)
n, bins = np.histogram(flight_time, bins=bin_array)
binwidth = np.diff(bins)[0]
N = n / binwidth / n_shots

n_true, _ = np.histogram(true_flight_time, bins=bin_array)
N_true = n_true / binwidth / n_shots

# Now average the detections
n_tot = np.sum(n)
binwidth_tot = t_sim_max - t_sim_min  # [s]
rho_avg_det = n_tot / binwidth_tot / n_shots  # [Hz]

n_tot_true = np.sum(n_true)
rho_avg_det_true = n_tot_true / binwidth_tot / n_shots  # [Hz]

# Plot
fig = plt.figure(figsize=(6,4), dpi=400)
plt.rcParams.update({'font.size': 15})
ax1 = fig.add_subplot(111)
center = 0.5 * (bins[:-1]+bins[1:])
ax1.bar((t_sim_max-t_sim_min-dt_sim)/2*3e8/2, rho_avg_det_true/1e6, width=(t_sim_max-t_sim_min-dt_sim)*3e8/2, align='center', color='#800020', alpha=0.50, label='True (Coarse)')
ax1.bar((t_sim_max-t_sim_min-dt_sim)/2*3e8/2, rho_avg_det/1e6/(1-rho_avg_det*tau), width=(t_sim_max-t_sim_min-dt_sim)*3e8/2, align='center', color='magenta', alpha=1, label='Standard Correction')
ax1.bar((t_sim_max-t_sim_min-dt_sim)/2*3e8/2, rho_avg_det/1e6, width=(t_sim_max-t_sim_min-dt_sim)*3e8/2, align='center', color='#800020', alpha=1, label='Detected (Coarse)')
ax1.bar(center*3e8/2, N_true/1e6, align='center', width=binwidth*3e8/2, color='b', alpha=0.5, label='True (Fine)')
# ax1.bar(center*3e8/2, N/1e6, align='center', width=binwidth*3e8/2, color='b', alpha=0.75, label='Detected Flux (Fine)')
# ax1.bar(center, N/1e6/(1-N*float(tau)), align='center', width=binwidth, color='cyan', alpha=0.25, label='High-Resolution Muller Flux')
ax1.set_xlabel('Range [m]')
ax1.set_ylabel('Flux [MHz]')
ax1.set_ylim([0, 26])
plt.legend()
plt.legend(loc='upper left', prop={'size': 11.5})
plt.tight_layout()
plt.show()
print('Histogram plot time elapsed: {:.3} sec'.format(time.time() - start))

print('Standard: {} MHz'.format(rho_avg_det/1e6/(1-rho_avg_det*tau)))
print('Truth: {} MHz'.format(rho_avg_det_true/1e6))
# Out:
# Histogram plot time elapsed: 3.85 sec
# Standard: <xarray.DataArray 'tD' ()>
# array(2.96700719) MHz
# Truth: 3.9131085 MHz

# %%
fname = r'\sim_amp2.5E+07_nshot1.0E+06_pwidth_1.2E+02.nc'
subdir = r'\subset_pwidth_1.2E+02\\'
ds = xr.open_dataset(save_dir + subdir + fname)

start = time.time()

cnts = ds.time_tag
cnts_true = ds.true_time_tag
tau = ds.tD
dt = dt_sim
flight_time = cnts * dt  # [s]
true_flight_time = cnts_true * dt  # [s]
# Exclude specified t.o.f. bins
flight_time = flight_time[np.where((flight_time >= window_bnd[0]) & (flight_time < window_bnd[1]))]
true_flight_time = true_flight_time[np.where((true_flight_time >= window_bnd[0]) & (true_flight_time < window_bnd[1]))]
n_shots = len(ds.sync_index)

ds.close()

bin_array = set_binwidth(t_sim_min, t_sim_max, dt)
n, bins = np.histogram(flight_time, bins=bin_array)
binwidth = np.diff(bins)[0]
N = n / binwidth / n_shots

n_true, _ = np.histogram(true_flight_time, bins=bin_array)
N_true = n_true / binwidth / n_shots

# Now average the detections
n_tot = np.sum(n)
binwidth_tot = t_sim_max - t_sim_min  # [s]
rho_avg_det = n_tot / binwidth_tot / n_shots  # [Hz]

n_tot_true = np.sum(n_true)
rho_avg_det_true = n_tot_true / binwidth_tot / n_shots  # [Hz]

# Plot
fig = plt.figure(figsize=(6,4), dpi=400)
plt.rcParams.update({'font.size': 15})
ax1 = fig.add_subplot(111)
center = 0.5 * (bins[:-1]+bins[1:])
# ax1.bar((t_sim_max-t_sim_min-dt_sim)/2*1e6, rho_avg_det_true/1e6, width=(t_sim_max-t_sim_min-dt_sim)*1e6, align='center', color='#800020', alpha=0.50, label='Low-Resolution True Flux')
# ax1.bar((t_sim_max-t_sim_min-dt_sim)/2*1e6, rho_avg_det/1e6/(1-rho_avg_det*tau), width=(t_sim_max-t_sim_min-dt_sim)*1e6, align='center', color='magenta', alpha=1, label='Müller Estimate')
# ax1.bar((t_sim_max-t_sim_min-dt_sim)/2*1e6, rho_avg_det/1e6, width=(t_sim_max-t_sim_min-dt_sim)*1e6, align='center', color='#800020', alpha=1, label='Low-Resolution Observed Flux')
ax1.bar(center*3e8/2, N/(1-N*29.1*1e-9)/1e6, width=binwidth*3e8/2, color='r', alpha=0.5, label='Standard Correction')
ax1.bar(center*3e8/2, N_true/1e6, align='center', width=binwidth*3e8/2, color='b', alpha=0.5, label='True Flux')
ax1.bar(center*3e8/2, N/1e6, align='center', width=binwidth*3e8/2, color='b', alpha=0.75, label='Observed Flux')
ax1.set_xlabel('Range [m]')
ax1.set_ylabel('Flux [MHz]')
plt.legend()
plt.legend(loc='upper left', prop={'size': 8})
plt.tight_layout()
plt.show()
print('Histogram plot time elapsed: {:.3} sec'.format(time.time() - start))
# Out:
# Histogram plot time elapsed: 2.36 sec

# %% [markdown]
# # Graveyard

# %% [markdown]
# # Compare Average Values
#
# If $\rho(t)$ is gaussian, then the average value over a single bin is
# $$\bar{\rho}(t)=\frac{1}{T}\int_{0}^{T}\rho(t')dt'=\frac{1}{T}\int_{0}^{T}\left(A\exp(-\frac{(t'-\mu)^2}{2\sigma^2})+b\right)dt'$$
# $$\bar{\rho}(t)=\frac{1}{T}\sqrt{\frac{\pi}{2}}A\sigma\left[erf\left(\frac{T-\mu}{\sqrt{2}\sigma}\right)-erf\left(-\frac{\mu}{\sqrt{2}\sigma}\right)\right]+b$$

# %%
# Analytic average of true function
erf = scipy.special.erf

T = t_sim_max - t_sim_min
A = amplitude  # [Hz]
sigma = laser_pulse_width  # [s]
mu = target_time  # [s]
b = background  # [Hz]

rho_avg_true = 1/T*np.sqrt(np.pi/2)*A*sigma*(erf((T-mu)/np.sqrt(2)/sigma)+b*T-erf(-mu/np.sqrt(2)/sigma))  # [Hz]
rho_avg_true = rho_avg_true[0]

# Now average the detections
n_tot = np.sum(n)
binwidth_tot = t_sim_max - t_sim_min  # [s]

rho_avg_det = n_tot / binwidth_tot / n_shots  # [Hz]

# Apply Muller correction
rho_avg_Muller = rho_avg_det / (1 - tD*rho_avg_det)
print('True avg flux: {:.2f} Hz'.format(rho_avg_true))
print('Detected avg flux: {:.2f} Hz'.format(rho_avg_det))
print('Muller corrected flux: {:.2f} Hz'.format(rho_avg_Muller))
# Out:
# True avg flux: 213909.23 Hz
# Detected avg flux: 210408.50 Hz
# Muller corrected flux: 211521.15 Hz
